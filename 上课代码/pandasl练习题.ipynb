# %%
import pandas as pd

# %%
# 模拟数据
data = {
    'movie_id': [1, 2, 3, 4, 5],
    'title': ['The Shawshank Redemption', 'The Godfather', 'Pulp Fiction', 'The Dark Knight', 'Forrest Gump'],
    'genre': ['Drama', 'Crime', 'Crime', 'Action', 'Drama'],
    'release_year': [1994, 1972, 1994, 2008, 1994],
    'rating': [9.3, 9.2, 8.9, 9.0, 8.8],
    'duration': [142, 175, 154, 152, 142]
}

df = pd.DataFrame(data)
df.to_csv('movies.csv', index=False)
df
# Out:
#    movie_id                     title   genre  release_year  rating  duration
# 0         1  The Shawshank Redemption   Drama          1994     9.3       142
# 1         2             The Godfather   Crime          1972     9.2       175
# 2         3              Pulp Fiction   Crime          1994     8.9       154
# 3         4           The Dark Knight  Action          2008     9.0       152
# 4         5              Forrest Gump   Drama          1994     8.8       142

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      5 non-null      int64
#  1   title         5 non-null      str
#  2   genre         5 non-null      str
#  3   release_year  5 non-null      int64
#  4   rating        5 non-null      float64
#  5   duration      5 non-null      int64
# dtypes: float64(1), int64(3), str(2)
# memory usage: 474.0 bytes

# %%
df.shape
# Out:
# (5, 6)

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'genre', 'release_year', 'rating', 'duration'], dtype='str')

# %%
df.index.to_list()
# Out:
# [0, 1, 2, 3, 4]

# %%
df.title
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2                Pulp Fiction
# 3             The Dark Knight
# 4                Forrest Gump
# Name: title, dtype: str

# %%
df.iloc[1,:]
# Out:
# movie_id                    2
# title           The Godfather
# genre                   Crime
# release_year             1972
# rating                    9.2
# duration                  175
# Name: 1, dtype: object

# %%
df.rating.head(3)
# Out:
# 0    9.3
# 1    9.2
# 2    8.9
# Name: rating, dtype: float64

# %%
df.release_year.tail(2)
# Out:
# 3    2008
# 4    1994
# Name: release_year, dtype: int64

# %%
df[df['rating']>9.0]
df.query('rating>9.0')
# Out:
#    movie_id                     title  genre  release_year  rating  duration
# 0         1  The Shawshank Redemption  Drama          1994     9.3       142
# 1         2             The Godfather  Crime          1972     9.2       175

# %%
df.query('release_year==1994')
# Out:
#    movie_id                     title  genre  release_year  rating  duration
# 0         1  The Shawshank Redemption  Drama          1994     9.3       142
# 2         3              Pulp Fiction  Crime          1994     8.9       154
# 4         5              Forrest Gump  Drama          1994     8.8       142

# %%
df.query("genre=='Crime'")
df[df['genre']=='Crime']
# Out:
#    movie_id          title  genre  release_year  rating  duration
# 1         2  The Godfather  Crime          1972     9.2       175
# 2         3   Pulp Fiction  Crime          1994     8.9       154

# %%
df.set_index('movie_id')
# Out:
#                              title   genre  release_year  rating  duration
# movie_id
# 1         The Shawshank Redemption   Drama          1994     9.3       142
# 2                    The Godfather   Crime          1972     9.2       175
# 3                     Pulp Fiction   Crime          1994     8.9       154
# 4                  The Dark Knight  Action          2008     9.0       152
# 5                     Forrest Gump   Drama          1994     8.8       142

# %%
df.reset_index(drop=True)
# Out:
#    movie_id                     title   genre  release_year  rating  duration
# 0         1  The Shawshank Redemption   Drama          1994     9.3       142
# 1         2             The Godfather   Crime          1972     9.2       175
# 2         3              Pulp Fiction   Crime          1994     8.9       154
# 3         4           The Dark Knight  Action          2008     9.0       152
# 4         5              Forrest Gump   Drama          1994     8.8       142

# %%
print(type(df.rating))
df.rating.dtype
# Out:
# <class 'pandas.Series'>
# dtype('float64')

# %%
df.dtypes
# Out:
# movie_id          int64
# title               str
# genre               str
# release_year      int64
# rating          float64
# duration          int64
# dtype: object

# %%
df.rating.sort_values()
# Out:
# 4    8.8
# 2    8.9
# 3    9.0
# 1    9.2
# 0    9.3
# Name: rating, dtype: float64

# %%
df.release_year.sort_values(ascending=False)
# Out:
# 3    2008
# 0    1994
# 2    1994
# 4    1994
# 1    1972
# Name: release_year, dtype: int64

# %%
df.rating.mean()
# Out:
# np.float64(9.040000000000001)

# %%
df.duration.max()
# Out:
# 175

# %%
df.duration.min()
# Out:
# 142

# %%
df.rating.median()
# Out:
# 9.0

# %%
df.rating.std()
# Out:
# 0.20736441353327703

# %%
df.genre.count()
# Out:
# np.int64(5)

# %%
df.describe()
# Out:
#        movie_id  release_year    rating    duration
# count  5.000000      5.000000  5.000000    5.000000
# mean   3.000000   1992.400000  9.040000  153.000000
# std    1.581139     12.915107  0.207364   13.490738
# min    1.000000   1972.000000  8.800000  142.000000
# 25%    2.000000   1994.000000  8.900000  142.000000
# 50%    3.000000   1994.000000  9.000000  152.000000
# 75%    4.000000   1994.000000  9.200000  154.000000
# max    5.000000   2008.000000  9.300000  175.000000

# %%
df[['title','rating']]
df.loc[:,['title','rating']]
df.iloc[:,[1,4]]
# Out:
#                       title  rating
# 0  The Shawshank Redemption     9.3
# 1             The Godfather     9.2
# 2              Pulp Fiction     8.9
# 3           The Dark Knight     9.0
# 4              Forrest Gump     8.8

# %%
df.iloc[:,1:4]
# Out:
#                       title   genre  release_year
# 0  The Shawshank Redemption   Drama          1994
# 1             The Godfather   Crime          1972
# 2              Pulp Fiction   Crime          1994
# 3           The Dark Knight  Action          2008
# 4              Forrest Gump   Drama          1994

# %%
df['rating']=df['rating']+1

# %%
df.duration-10
# Out:
# 0    132
# 1    165
# 2    144
# 3    142
# 4    132
# Name: duration, dtype: int64

# %%
df.query('rating>9.5')
# Out:
#    movie_id                     title   genre  release_year  rating  duration
# 0         1  The Shawshank Redemption   Drama          1994    10.3       142
# 1         2             The Godfather   Crime          1972    10.2       175
# 2         3              Pulp Fiction   Crime          1994     9.9       154
# 3         4           The Dark Knight  Action          2008    10.0       152
# 4         5              Forrest Gump   Drama          1994     9.8       142

# %%
df.query('rating>9.5&release_year==1994')
# Out:
#    movie_id                     title  genre  release_year  rating  duration
# 0         1  The Shawshank Redemption  Drama          1994    10.3       142
# 2         3              Pulp Fiction  Crime          1994     9.9       154
# 4         5              Forrest Gump  Drama          1994     9.8       142

# %%
df['title'].str.contains('The')
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: title, dtype: bool

# %%
df[df['title'].str.contains('The')]
# Out:
#    movie_id                     title   genre  release_year  rating  duration
# 0         1  The Shawshank Redemption   Drama          1994    10.3       142
# 1         2             The Godfather   Crime          1972    10.2       175
# 3         4           The Dark Knight  Action          2008    10.0       152

# %%
df.rating.head(3).reset_index()
# Out:
#    index  rating
# 0      0    10.3
# 1      1    10.2
# 2      2     9.9

# %%
df.rating.round(1)
# Out:
# 0    10.3
# 1    10.2
# 2     9.9
# 3    10.0
# 4     9.8
# Name: rating, dtype: float64

# %%
df.rating.cumsum()
# Out:
# 0    10.3
# 1    20.5
# 2    30.4
# 3    40.4
# 4    50.2
# Name: rating, dtype: float64

# %%
df.duration.cummax()
# Out:
# 0    142
# 1    175
# 2    175
# 3    175
# 4    175
# Name: duration, dtype: int64

# %%
df.to_csv('new_movies.csv',index=False)

# %%
s=df.rating

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.values
# Out:
# array([10.3, 10.2,  9.9, 10. ,  9.8])

# %%
s.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: rating
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      float64
# dtypes: float64(1)
# memory usage: 172.0 bytes
